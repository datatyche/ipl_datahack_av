# %%
import pandas as pd
ball_by_ball = pd.read_csv('../resources/train/ball_by_ball_data.csv')
match_data = pd.read_csv('../resources/train/match_data.csv')
bbb_venue = ball_by_ball.merge(match_data, on='match_id')
bbb_venue.head(n=2)
# Out:
#   match_id  inning batting_team bowling_team  over  ball       batsman  \
# 0   2017_1       1          SRH          RCB     1     1  David Warner
# 1   2017_1       1          SRH          RCB     1     2  David Warner
#
#    batsman_id     non_striker  non_striker_id    ...    dl_applied  winner  \
# 0         207  Shikhar Dhawan              57    ...             0     SRH
# 1         207  Shikhar Dhawan              57    ...             0     SRH
#
#    win_by_runs  win_by_wickets player_of_match  player_of_match_id  \
# 0           35               0    Yuvraj Singh                88.0
# 1           35               0    Yuvraj Singh                88.0
#
#                                            venue  venue_id      umpire1  \
# 0  Rajiv Gandhi International Stadium, Hyderabad         4  AY Dandekar
# 1  Rajiv Gandhi International Stadium, Hyderabad         4  AY Dandekar
#
#     umpire2
# 0  NJ Llong
# 1  NJ Llong
#
# [2 rows x 36 columns]

# %%
bat_sat = bbb_venue[['batsman_id', 'match_id', 'season', 'bowling_team', 'venue_id', 'batsman_runs']]

bat_sat_agg = bbb_venue.groupby(['batsman_id', 'season', 'bowling_team', 'venue_id']).agg({'batsman_runs': np.sum}).reset_index()
bat_sat_agg.head(n=2)
# Out:
#    batsman_id  season bowling_team  venue_id  batsman_runs
# 0           1    2008           DC         4            37
# 1           1    2008           DC         5            23

# %%
bat_run_group = bbb_venue[bbb_venue['extra_runs'] == 0].groupby(['batsman_id', 'season', 'bowling_team', 'venue_id', 'batsman_runs']).agg({'match_id': np.size}).reset_index()
bat_run_group.head(n = 10)
# Out:
#    batsman_id  season bowling_team  venue_id  batsman_runs  match_id
# 0           1    2008           DC         4             0         7
# 1           1    2008           DC         4             1         9
# 2           1    2008           DC         4             2         3
# 3           1    2008           DC         4             4         4
# 4           1    2008           DC         4             6         1
# 5           1    2008           DC         5             0        18
# 6           1    2008           DC         5             1         7
# 7           1    2008           DC         5             2         4
# 8           1    2008           DC         5             4         2
# 9           1    2008           DD         2             0        10

# %%
for i in [0,1,2,3,4,6]:
    cname = str(i) + "_runs"
    bat_run_group[cname] = bat_run_group.apply(lambda x: x.match_id if x.batsman_runs == i else 0, axis = 1)
    
bat_run_group.head(n=10)
# Out:
#    batsman_id  season bowling_team  venue_id  batsman_runs  match_id  0_runs  \
# 0           1    2008           DC         4             0         7       7
# 1           1    2008           DC         4             1         9       0
# 2           1    2008           DC         4             2         3       0
# 3           1    2008           DC         4             4         4       0
# 4           1    2008           DC         4             6         1       0
# 5           1    2008           DC         5             0        18      18
# 6           1    2008           DC         5             1         7       0
# 7           1    2008           DC         5             2         4       0
# 8           1    2008           DC         5             4         2       0
# 9           1    2008           DD         2             0        10      10
#
#    1_runs  2_runs  3_runs  4_runs  6_runs
# 0       0       0       0       0       0
# 1       9       0       0       0       0
# 2       0       3       0       0       0
# 3       0       0       0       4       0
# 4       0       0       0       0       1
# 5       0       0       0       0       0
# 6       7       0       0       0       0
# 7       0       4       0       0       0
# 8       0       0       0       2       0
# 9       0       0       0       0       0

# %%
bat_run_class = bat_run_group.groupby(['batsman_id', 'season', 'bowling_team', 'venue_id']).agg({'0_runs': np.sum, '1_runs': np.sum, '2_runs': np.sum, '3_runs': np.sum, '4_runs': np.sum, '6_runs': np.sum}).reset_index()
bat_run_class.head(n =10)
# Out:
#    batsman_id  season bowling_team  venue_id  0_runs  1_runs  2_runs  3_runs  \
# 0           1    2008           DC         4       7       9       3       0
# 1           1    2008           DC         5      18       7       4       0
# 2           1    2008           DD         2      10      15       3       0
# 3           1    2008           DD         5       8      14       2       0
# 4           1    2008          KKR         5       6      13       3       0
# 5           1    2008          KXI         5      12      17       4       1
# 6           1    2008          KXI         9       1       2       0       0
# 7           1    2008           MI         1      14      11       1       0
# 8           1    2008           MI         5       4       4       2       0
# 9           1    2008          RCB         5       5       2       1       0
#
#    4_runs  6_runs
# 0       4       1
# 1       2       0
# 2       3       0
# 3       2       1
# 4       3       2
# 5       2       4
# 6       0       0
# 7       6       1
# 8       4       1
# 9       0       0
